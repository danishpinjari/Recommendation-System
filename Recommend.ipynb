# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
# Generating 1000 user IDs
user_ids = [f'U{i}' for i in range(1, 1001)]

# %%
data = pd.read_csv('Skillset.csv')
skills = data['skills'].tolist()

# %%
data.head()
# Out:
#                  skills
# 0                Python
# 1      Machine Learning
# 2         Data Analysis
# 3  Statistical Modeling
# 4    Data Visualization

# %%
# Remove duplicates (if any)
skills = list(set(skills))

# %%
# Initialize DataFrame with 0s
data = pd.DataFrame(0, index=user_ids, columns=skills)

# %%
# Assign each user between 10 and 30 random skills to increase overlap
np.random.seed(0)  # For reproducibility
for user_id in user_ids:
    num_skills = np.random.randint(10, 50)
    assigned_skills = np.random.choice(skills, num_skills, replace=False)
    data.loc[user_id, assigned_skills] = 1

# %%
# Function to get skills assigned to a specific user
def get_user_skills(user_id):
    assigned_skills = data.columns[data.loc[user_id] == 1].tolist()
    return assigned_skills

# %%
# Compute cosine similarity
cosine_sim = cosine_similarity(data)
cosine_sim_df = pd.DataFrame(cosine_sim, index=user_ids, columns=user_ids)

# %%
# Create a matrix showing the similarity percentage between each user pair
similarity_percentage_matrix = cosine_sim_df * 100

# %%
# Convert the matrix to a DataFrame for better readability
similarity_percentage_df = pd.DataFrame(similarity_percentage_matrix, index=user_ids, columns=user_ids)

# %%
# Save DataFrames to pickle files
with open('current_skills.pkl', 'wb') as f:
    pickle.dump(data, f)

with open('similarity_scores.pkl', 'wb') as f:
    pickle.dump(similarity_percentage_df, f)

# %%
# Function to get similar users with unique scores for a specific user
def get_unique_similar_users(user_id, threshold=20.0):
    similarity_percentages = similarity_percentage_df[user_id]
    similar_users = similarity_percentages[similarity_percentages >= threshold].to_dict()
    if user_id in similar_users:
        del similar_users[user_id]  # Remove the user itself from the dictionary
    return {user_id: similar_users}

# %%
# Function to recommend skills to a user based on users with at least a specified similarity threshold
def recommend_skills(user_id, similarity_threshold=20.0):
    similar_users_with_scores = get_unique_similar_users(user_id, similarity_threshold)
    
    # Print similar users with scores
    print(f"Similar users with scores for user {user_id}: {similar_users_with_scores}")

    user_skills = set(get_user_skills(user_id))
    print(f"Current skills of user {user_id}: {user_skills}")

    recommended_skills = set()
    user_scores = {}

    for similar_user, scores in similar_users_with_scores[user_id].items():
        similar_user_skills = set(get_user_skills(similar_user))
        new_skills = similar_user_skills - user_skills
        print(f"New skills from user {similar_user} to recommend: {new_skills}")
        recommended_skills.update(new_skills)
        # Store the score for each similar user
        user_scores[similar_user] = scores

    return recommended_skills, user_scores

# %%
# Example: Recommend skills for user U300
recommended_skills, user_scores = recommend_skills('U85', similarity_threshold=25.0)
print(f"Recommended skills for user : {recommended_skills}")
print(f"Scores of similar users : {user_scores}")
# Out:
# Similar users with scores for user U85: {'U85': {}}
# Current skills of user U85: {'Competitive Analysis', 'Data Scaling', 'Web Ontologies', 'Campaign Management', 'Environmental Analytics', 'User Stories', 'Supply Chain Analytics', 'Technical Support', 'Mathematics', 'Statistical Process Control', 'Content Strategy', 'Occupational Health', 'User Guides', 'Metrics', 'Qualitative Research', 'Recruitment', 'Flask', 'Clinical Trials', 'Sprint Retrospective', 'NoSQL', 'Data Cataloging', 'System Testing', 'Training and Development', 'AWS', 'Data Management Tools', 'HIPAA', 'Compliance Management', 'Data Loading', 'Profitability Analysis', 'Trade Shows', 'Continuous Deployment', 'Reporting', 'Password Management', 'ETL Processes', 'Feature Selection', 'Event Sourcing', 'Artificial Intelligence', 'Content Analytics', 'Smart Cities', 'SOX', 'Computational Statistics', 'SQL Server', 'Event-Driven Architecture', 'Grid Search', 'Cassandra', 'Recurrent Neural Networks', 'Kaizen', 'Interviews'}
# Recommended skills for user : set()
# Scores of similar users : {}

# %%
pickle.load(open('current_skills.pkl','rb'))
# Out:
#        Lab Experiments  Data Anonymization  Web Ontologies  Profiling  \
# U1                   0                   0               0          0
# U2                   0                   0               0          0
# U3                   0                   0               0          0
# U4                   0                   0               0          0
# U5                   0                   0               0          0
# ...                ...                 ...             ...        ...
# U996                 0                   0               0          0
# U997                 0                   0               0          0
# U998                 0                   0               0          0
# U999                 0                   0               0          0
# U1000                0                   0               0          0
#
#        Data Extraction  Mathematics  Product Development  Business Rules  \
# U1                   0            0                    0               0
# U2                   0            0                    0               0
# U3                   0            0                    1               0
# U4                   0            0                    0               0
# U5                   0            0                    0               0
# ...                ...          ...                  ...             ...
# U996                 0            0                    0               0
# U997                 0            0                    0               0
# U998                 0            0                    0               0
# U999                 0            0                    0               0
# U1000                0            0                    0               0
#
#        R Programming  Compliance Management  ...  Data Encryption  \
# U1                 0                      0  ...                0
# U2                 0                      0  ...                0
# U3                 0                      0  ...                0
# U4                 1                      0  ...                0
# U5                 0                      0  ...                0
# ...              ...                    ...  ...              ...
# U996               0                      0  ...                0
# U997               0                      0  ...                0
# U998               0                      1  ...                0
# U999               0                      0  ...                0
# U1000              0                      0  ...                0
#
#        Data Pseudonymization  Data Generation  Security Testing  \
# U1                         0                0                 1
# U2                         0                0                 0
# U3                         0                0                 0
# U4                         0                0                 1
# U5                         0                0                 0
# ...                      ...              ...               ...
# U996                       0                0                 1
# U997                       0                0                 0
# U998                       0                0                 1
# U999                       0                0                 0
# U1000                      0                0                 1
#
#        Model Maintenance  Product Management  Deep Learning  Product Roadmap  \
# U1                     0                   0              0                0
# U2                     0                   0              0                0
# U3                     0                   0              0                0
# U4                     0                   0              0                1
# U5                     0                   0              0                0
# ...                  ...                 ...            ...              ...
# U996                   0                   0              0                0
# U997                   0                   0              0                0
# U998                   0                   0              0                0
# U999                   0                   0              0                0
# U1000                  1                   1              1                0
#
#        Computational Statistics  Scikit-Learn
# U1                            0             0
# U2                            0             0
# U3                            0             0
# U4                            0             0
# U5                            0             0
# ...                         ...           ...
# U996                          0             0
# U997                          1             0
# U998                          0             0
# U999                          0             0
# U1000                         0             0
#
# [1000 rows x 495 columns]

# %%
pickle.load(open('similarity_scores.pkl','rb'))
# Out:
#                U1          U2          U3          U4          U5        U6  \
# U1     100.000000    0.000000    0.000000    5.063697    8.451543  0.000000
# U2       0.000000  100.000000   11.322770   18.490007   11.572751  0.000000
# U3       0.000000   11.322770  100.000000    9.421114    0.000000  4.902903
# U4       5.063697   18.490007    9.421114  100.000000    4.279605  4.003204
# U5       8.451543   11.572751    0.000000    4.279605  100.000000  6.681531
# ...           ...         ...         ...         ...         ...       ...
# U996    13.187609    6.019293    4.089304   10.016708    0.000000  0.000000
# U997    16.035675   19.518001    3.314968    2.706660    4.517540  0.000000
# U998     6.593805    3.009646    4.089304   13.355611    5.572782  0.000000
# U999     0.000000    8.703883   11.826248    0.000000    0.000000  7.537784
# U1000    5.270463    9.622504    9.805807   16.012815    0.000000  8.333333
#
#               U7         U8         U9       U10  ...       U991       U992  \
# U1      0.000000   0.000000   5.345225  9.225312  ...   0.000000  12.649111
# U2     10.825318  17.407766   2.439750  8.421519  ...   9.622504  11.547005
# U3      0.000000   5.913124   6.629935  2.860648  ...   9.805807   3.922323
# U4      0.000000  14.484136   5.413320  4.671418  ...   8.006408   3.202563
# U5      0.000000   0.000000   0.000000  3.898406  ...  13.363062   5.345225
# ...          ...        ...        ...       ...  ...        ...        ...
# U996   10.425721   0.000000   3.524537  3.041495  ...   6.950480   8.340577
# U997    0.000000   5.096472   8.571429  7.396705  ...   2.817181  10.141851
# U998   10.425721   0.000000   7.049074  0.000000  ...   0.000000   0.000000
# U999    0.000000   0.000000   0.000000  8.795990  ...   0.000000   0.000000
# U1000   0.000000  20.100756  11.268723  4.862166  ...   8.333333   3.333333
#
#             U993       U994      U995        U996        U997        U998  \
# U1      6.324555   5.129892  0.000000   13.187609   16.035675    6.593805
# U2      2.886751   9.365858  0.000000    6.019293   19.518001    3.009646
# U3     11.766968   9.544271  8.770580    4.089304    3.314968    4.089304
# U4      6.405126   2.597622  7.161149   10.016708    2.706660   13.355611
# U5     10.690450   0.000000  0.000000    0.000000    4.517540    5.572782
# ...          ...        ...       ...         ...         ...         ...
# U996    8.340577   3.382550  0.000000  100.000000    7.049074    4.347826
# U997    0.000000  24.678382  3.779645    7.049074  100.000000   10.573611
# U998    8.340577   3.382550  0.000000    4.347826   10.573611  100.000000
# U999    0.000000   0.000000  0.000000    0.000000    5.096472   12.573892
# U1000  16.666667  13.518452  7.453560    3.475240    5.634362    6.950480
#
#              U999       U1000
# U1       0.000000    5.270463
# U2       8.703883    9.622504
# U3      11.826248    9.805807
# U4       0.000000   16.012815
# U5       0.000000    0.000000
# ...           ...         ...
# U996     0.000000    3.475240
# U997     5.096472    5.634362
# U998    12.573892    6.950480
# U999   100.000000    0.000000
# U1000    0.000000  100.000000
#
# [1000 rows x 1000 columns]

# %%
# Function to add a new user and recommend skills based on existing users
def add_new_user(new_user_id, current_skills, similarity_threshold=90.0):
    # Create a row for the new user in the existing DataFrame with current skills
    new_user_row = pd.Series(0, index=data.columns)
    for skill in current_skills:
        if skill in new_user_row.index:
            new_user_row[skill] = 1
    data.loc[new_user_id] = new_user_row

    # Recompute cosine similarity with the new user added
    cosine_sim = cosine_similarity(data)
    cosine_sim_df = pd.DataFrame(cosine_sim, index=data.index, columns=data.index)
    similarity_percentage_matrix = cosine_sim_df * 100
    similarity_percentage_df = pd.DataFrame(similarity_percentage_matrix, index=data.index, columns=data.index)
    
    # Save updated DataFrames to pickle files
    with open('current_skills.pkl', 'wb') as f:
        pickle.dump(data, f)
    
    with open('similarity_scores.pkl', 'wb') as f:
        pickle.dump(similarity_percentage_df, f)

    # Recommend skills for the new user
    recommended_skills, user_scores = recommend_skills(new_user_id, similarity_threshold)
    return recommended_skills, user_scores

# %%
# Example: Adding a new user U1001 with some skills
new_user_id = 'U104'
new_user_skills = ['Python', 'Data Visualization']
recommended_skills, user_scores = add_new_user(new_user_id, new_user_skills, similarity_threshold=21.0)
# Out:
# Similar users with scores for user U104: {'U104': {'U36': 23.159177829329273, 'U58': 21.053798026662975, 'U292': 21.290467263536573, 'U366': 23.159177829329273, 'U955': 21.053798026662975}}
# Current skills of user U104: {'Python', 'Data Visualization'}
# New skills from user U36 to recommend: {'Synthetic Data Generation', 'Graph Databases', 'Market Basket Analysis', 'Sales Strategy', 'APIs', 'Dispute Resolution', 'Use Cases', 'SWOT Analysis', 'Social Media Analytics', 'Data Integration', 'Product Development', 'Unani', 'Cloud Security', 'Stream Processing', 'Risk Mitigation', 'Business Analytics', 'NoSQL', 'Sprint Review', 'AI Policy', 'Workforce Planning', 'Key Performance Indicators', 'Data Cleaning', 'Scikit-Learn', 'Sales Forecasting', 'User Profiling', 'Financial Analytics', 'Innovation', 'Missing Data Handling', 'Object Detection', 'Work-Life Balance', 'Continuous Deployment', 'Business Process Management', 'Regulations', 'Unsupervised Learning', 'Research and Development', 'SPARQL', 'Retail Analytics', 'Product Launch', 'Data Governance', 'Computational Statistics', 'Augmented Reality', 'Failure Modes and Effects Analysis', 'Backup and Recovery', 'Big Data', 'Interviews', 'Change Control', 'Customer Success', 'Data Quality'}
# New skills from user U58 to recommend: {'Benchmarking', 'Kanban', 'Profitability Analysis', 'Employee Wellness', 'Product Design', 'Critical Path Method', 'Code Documentation', 'Data Transparency', 'Talent Management', 'Urban Analytics', 'Agricultural Analytics', 'GraphQL'}
# New skills from user U292 to recommend: {'Forensics', 'IoT', 'Benchmarking', 'Network Security', 'Data Anonymization', 'Flowcharts', 'Legal Compliance', 'Performance Testing', 'Public Relations', 'Smart Devices', 'Time Series Analysis', 'Information Security', 'Semi-supervised Learning', 'Corporate Social Responsibility', 'Wearable Technology', 'Requirements Gathering', 'Load Testing', 'Data Governance', 'Metadata Management', 'Data Science', 'MBBS', 'Graph Theory', 'Trend Analysis'}
# New skills from user U366 to recommend: {'Customer Experience', 'Competitive Analysis', 'Data Analytics', 'Scalability', 'Model Monitoring', 'Partnerships', 'Networking', 'Development Team', 'Fairness in AI', 'Metrics', 'Metadata Management', 'Fault Tolerance', 'Sprint Retrospective', 'NoSQL', 'RDF', 'AI Policy', 'Configuration Management', 'Scrum Master', 'Agricultural Analytics', 'Incident Response', 'Customer Feedback', 'Customer Journey Mapping', 'Scikit-Learn', 'Security in AI', 'Data Unification', 'Product Owner', 'Trademark Law', 'Continuous Deployment', 'Smart Devices', 'Reporting', 'CI/CD', 'Retail Analytics', 'SOX', 'Business Development', 'Training Materials', 'Agile Practices', 'Process Optimization', 'Performance Management', 'Human-Computer Interaction', 'Computer Vision', 'Identity Management', 'Quality Control', 'Issue Tracking', 'Usability Testing', 'Change Control', 'Version Control', 'Executive Management'}
# New skills from user U955 to recommend: {'Model Evaluation', 'Pharmacovigilance', 'Network Security', 'Backlog Refinement', 'Lean', 'Lab Technichian', 'Message Queues', 'Order Fulfillment', 'Model Monitoring', 'Risk Register', 'ITIL', 'Focus Groups', 'Transfer Learning', 'Webinars', 'CCPA', 'Sentiment Analysis', 'Business Analytics', 'Integration Testing', 'Statistical Modeling', 'Hyperparameter Tuning', 'NoSQL', 'Graph Theory', 'Power BI', 'SEM', 'Service Management', 'PyTorch', 'Quality Assurance', 'Product Owner', 'Synthetic Data', 'Access Control', 'White Hat Hacking', 'Authentication', 'Data Encryption', 'Health and Safety', 'Optimization Algorithms', 'Urban Analytics', 'Unsupervised Learning', 'Research and Development', 'Business Development', 'Credit Scoring', 'Deep Learning', 'Process Optimization', 'Git', 'User Experience', 'Technical Writing', 'Penetration Testing', 'Swimlane Diagrams', 'Speech Recognition'}

# %%
print(f"Recommended skills for new user {new_user_id}: {recommended_skills}")
print(f"Scores of similar users for new user {new_user_id}: {user_scores}")
# Out:
# Recommended skills for new user U104: {'Competitive Analysis', 'Graph Databases', 'Market Basket Analysis', 'Network Security', 'Data Anonymization', 'Product Design', 'ITIL', 'Product Development', 'Partnerships', 'Fairness in AI', 'Sprint Retrospective', 'NoSQL', 'AI Policy', 'Key Performance Indicators', 'Service Management', 'Innovation', 'Data Unification', 'Quality Assurance', 'Smart Devices', 'Code Documentation', 'Health and Safety', 'Corporate Social Responsibility', 'Retail Analytics', 'GraphQL', 'Agile Practices', 'Process Optimization', 'Critical Path Method', 'Augmented Reality', 'Human-Computer Interaction', 'User Experience', 'Penetration Testing', 'Usability Testing', 'Change Control', 'Swimlane Diagrams', 'Speech Recognition', 'Backlog Refinement', 'Lean', 'SWOT Analysis', 'Social Media Analytics', 'Message Queues', 'Data Integration', 'Order Fulfillment', 'Information Security', 'Model Monitoring', 'Wearable Technology', 'Unani', 'Requirements Gathering', 'Risk Mitigation', 'Employee Wellness', 'Metadata Management', 'Hyperparameter Tuning', 'Sprint Review', 'Workforce Planning', 'Configuration Management', 'Agricultural Analytics', 'Incident Response', 'Data Cleaning', 'Trend Analysis', 'SEM', 'Missing Data Handling', 'Public Relations', 'Kanban', 'Object Detection', 'Profitability Analysis', 'Product Owner', 'Synthetic Data', 'Continuous Deployment', 'Reporting', 'Unsupervised Learning', 'Urban Analytics', 'Optimization Algorithms', 'Performance Management', 'Computer Vision', 'Technical Writing', 'Big Data', 'Executive Management', 'Flowcharts', 'Pharmacovigilance', 'Sales Strategy', 'Legal Compliance', 'Use Cases', 'Dispute Resolution', 'Networking', 'Development Team', 'CCPA', 'Sentiment Analysis', 'Metrics', 'Business Analytics', 'Statistical Modeling', 'Fault Tolerance', 'RDF', 'Customer Feedback', 'Power BI', 'Scikit-Learn', 'Security in AI', 'PyTorch', 'Authentication', 'Business Process Management', 'CI/CD', 'SPARQL', 'Business Development', 'Training Materials', 'Data Governance', 'Failure Modes and Effects Analysis', 'Identity Management', 'Data Transparency', 'Backup and Recovery', 'Interviews', 'Version Control', 'Customer Journey Mapping', 'Model Evaluation', 'Forensics', 'IoT', 'Synthetic Data Generation', 'Benchmarking', 'Customer Experience', 'APIs', 'Data Analytics', 'Lab Technichian', 'Scalability', 'Time Series Analysis', 'Semi-supervised Learning', 'Talent Management', 'Risk Register', 'Focus Groups', 'Cloud Security', 'Transfer Learning', 'Stream Processing', 'Webinars', 'Integration Testing', 'Data Science', 'Graph Theory', 'Scrum Master', 'Sales Forecasting', 'User Profiling', 'Financial Analytics', 'Performance Testing', 'Access Control', 'White Hat Hacking', 'Trademark Law', 'Work-Life Balance', 'Data Encryption', 'Regulations', 'Research and Development', 'Product Launch', 'SOX', 'Load Testing', 'Credit Scoring', 'Deep Learning', 'Git', 'MBBS', 'Quality Control', 'Issue Tracking', 'Computational Statistics', 'Customer Success', 'Data Quality'}
# Scores of similar users for new user U104: {'U36': 23.159177829329273, 'U58': 21.053798026662975, 'U292': 21.290467263536573, 'U366': 23.159177829329273, 'U955': 21.053798026662975}
