# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
# Generating 1000 user IDs
user_ids = [f'U{i}' for i in range(1, 1001)]

# %%
data = pd.read_csv('../backend/Skillset.csv')
skills = data['skills'].tolist()

# %%
data.head()
# Out:
#                  skills
# 0                Python
# 1      Machine Learning
# 2         Data Analysis
# 3  Statistical Modeling
# 4    Data Visualization

# %%
# Remove duplicates (if any)
skills = list(set(skills))

# %%
# Initialize DataFrame with 0s
data = pd.DataFrame(0, index=user_ids, columns=skills)

# %%
# Assign each user between 10 and 30 random skills to increase overlap
np.random.seed(0)  # For reproducibility
for user_id in user_ids:
    num_skills = np.random.randint(10, 50)
    assigned_skills = np.random.choice(skills, num_skills, replace=False)
    data.loc[user_id, assigned_skills] = 1

# %%
# Function to get skills assigned to a specific user
def get_user_skills(user_id):
    assigned_skills = data.columns[data.loc[user_id] == 1].tolist()
    return assigned_skills

# %%
# Compute cosine similarity
cosine_sim = cosine_similarity(data)
cosine_sim_df = pd.DataFrame(cosine_sim, index=user_ids, columns=user_ids)

# %%
# Create a matrix showing the similarity percentage between each user pair
similarity_percentage_matrix = cosine_sim_df * 100

# %%
# Convert the matrix to a DataFrame for better readability
similarity_percentage_df = pd.DataFrame(similarity_percentage_matrix, index=user_ids, columns=user_ids)

# %%
# Save DataFrames to pickle files
with open('current_skills.pkl', 'wb') as f:
    pickle.dump(data, f)

with open('similarity_scores.pkl', 'wb') as f:
    pickle.dump(similarity_percentage_df, f)

# %%
# Function to get similar users with unique scores for a specific user
def get_unique_similar_users(user_id, threshold=20.0):
    similarity_percentages = similarity_percentage_df[user_id]
    similar_users = similarity_percentages[similarity_percentages >= threshold].to_dict()
    if user_id in similar_users:
        del similar_users[user_id]  # Remove the user itself from the dictionary
    return {user_id: similar_users}

# %%
# Function to recommend skills to a user based on users with at least a specified similarity threshold
def recommend_skills(user_id, similarity_threshold=20.0):
    similar_users_with_scores = get_unique_similar_users(user_id, similarity_threshold)
    
    # Print similar users with scores
    print(f"Similar users with scores for user {user_id}: {similar_users_with_scores}")

    user_skills = set(get_user_skills(user_id))
    print(f"Current skills of user {user_id}: {user_skills}")

    recommended_skills = set()
    user_scores = {}

    for similar_user, scores in similar_users_with_scores[user_id].items():
        similar_user_skills = set(get_user_skills(similar_user))
        new_skills = similar_user_skills - user_skills
        print(f"New skills from user {similar_user} to recommend: {new_skills}")
        recommended_skills.update(new_skills)
        # Store the score for each similar user
        user_scores[similar_user] = scores

    return recommended_skills, user_scores

# %%
# Example: Recommend skills for user U300
recommended_skills, user_scores = recommend_skills('U104', similarity_threshold=21.0)
print(f"Recommended skills for user : {recommended_skills}")
print(f"Scores of similar users : {user_scores}")
# Out:
# Similar users with scores for user U104: {'U104': {'U36': 23.159177829329273, 'U58': 21.053798026662975, 'U292': 21.290467263536573, 'U366': 23.159177829329273, 'U955': 21.053798026662975}}
# Current skills of user U104: {'AWS', 'Succession Planning', 'Onboarding', 'Go-to-Market Strategy', 'Data Aggregation', 'Power BI', 'CCPA', 'User Research', 'CQRS', 'Benchmarking', 'Tableau', 'Qualitative Research', 'Data Transformation', 'Artificial Intelligence', 'Data Cleaning', 'Backlog Refinement', 'Gantt Charts', 'Data Sharing', 'Reporting', 'Agricultural Analytics', 'Social Media Analytics', 'Recommender Algorithms', 'Hybrid Filtering', 'Cybersecurity', 'Operations Research', 'Notebooks', 'Data Augmentation', 'Root Cause Analysis', 'SQL', 'Product Management', 'Data Integrity', 'CI/CD', 'Ethical Business Practices', 'Metrics', 'Workplace Culture', 'Compliance Management', 'SWOT Analysis', 'UI Design', 'Fraud Detection', 'Cost-Benefit Analysis', 'Database Sharding', 'Collaborations', 'R Programming', 'Technical Writing', 'Process Optimization', 'Documentation', 'Wearable Technology'}
# New skills from user U36 to recommend: {'Behavioral Analytics', 'Computational Statistics', 'Data Loading', 'Backup and Recovery', 'Recommendation Systems', 'Synthetic Data Generation', 'Ad Tech', 'Unani', 'Event Sourcing', 'Stream Processing', 'User Feedback', 'Corporate Social Responsibility', 'Employee Wellness', 'Flowcharts', 'Diversity and Inclusion', 'Vulnerability Assessment', 'Usability Testing', 'Marketing Automation', 'Board of Directors', 'Batch Processing', 'Fault Tolerance', 'Ethical Hacking', 'Lab Experiments', 'Data Synthesis', 'Generative Adversarial Networks', 'Legal Compliance', 'Networking', 'Semi-supervised Learning', 'Contracts', 'Business Rules', 'Regulatory Affairs', 'Experiment Tracking', 'Patent Law', 'Pharmacovigilance', 'Blue Teaming', 'Lead Generation', 'Alerting'}
# New skills from user U58 to recommend: {'Google Cloud', 'Segmentation', 'Model Deployment', 'Optimization Algorithms', 'Random Search', 'Content Analytics', 'Profiling'}
# New skills from user U292 to recommend: {'Feature Extraction', 'Data Masking', 'Model Deployment', 'Product Design', 'Scalability', 'SPARQL', 'Customer Support', 'Customer Insights', 'Message Brokers', 'Data Cataloging', 'Business Development', 'Vendor Management', 'Blue Teaming', 'Model Maintenance', 'Service Management', 'Statistics'}
# New skills from user U366 to recommend: {'Azure', 'Failure Modes and Effects Analysis', 'Oracle', 'Synthetic Data', 'Mediation', 'Collaborative Filtering', 'Interviews', 'Lean', 'Penetration Testing', 'Information Security', 'ITIL', 'Market Research', 'Unsupervised Learning', 'A/B Testing', 'Identity Management', 'Logistics Management', 'Occupational Health', 'Compensation and Benefits', 'Continuous Deployment', 'Scrum', 'PyTorch', 'Smart Cities', 'Data Simulation', 'Quantitative Research', 'Cost Estimation', 'Semi-supervised Learning', 'GraphQL', 'Sprint Planning', 'Web Ontologies', 'Copyright Law', 'Sales Strategy', 'Regulations', 'Supply Chain Management', 'AI Policy', 'Business Rules', 'Continuous Improvement', 'Alerting'}
# New skills from user U955 to recommend: {'Contract Management', 'Intellectual Property', 'Budgeting', 'Surveys', 'Web Scraping', 'Data Scaling', 'Regression Analysis', 'Big Data', 'Market Research', 'Problem Management', 'Regression Testing', 'TensorFlow', 'Random Search', 'Ethics in AI', 'Metadata Management', 'Data Transparency', 'Conferences', 'Load Testing', 'Employee Wellness', 'Encryption Standards', 'Continuous Deployment', 'Agile Practices', 'Prototyping', 'ROI', 'Data Management Tools', 'Discrete Mathematics', 'Knowledge Graphs', 'Supervised Learning', 'Robust AI', 'Trademark Law', 'Web Ontologies', 'Media Relations', 'Sales Strategy', 'Calculus', 'Risk Management', 'Normalization', 'Time Series Analysis', 'User Guides'}
# Recommended skills for user : {'Azure', 'Scalability', 'Mediation', 'Collaborative Filtering', 'Backup and Recovery', 'Recommendation Systems', 'Synthetic Data Generation', 'Pharmacovigilance', 'Information Security', 'Model Deployment', 'ITIL', 'Unsupervised Learning', 'Problem Management', 'A/B Testing', 'Logistics Management', 'Occupational Health', 'Vendor Management', 'Ethics in AI', 'Metadata Management', 'Data Transparency', 'Statistics', 'User Feedback', 'Load Testing', 'Flowcharts', 'Continuous Deployment', 'Agile Practices', 'Vulnerability Assessment', 'Prototyping', 'Data Cataloging', 'Data Management Tools', 'Scrum', 'Marketing Automation', 'Discrete Mathematics', 'Fault Tolerance', 'Ethical Hacking', 'Lab Experiments', 'Smart Cities', 'Model Maintenance', 'Service Management', 'Generative Adversarial Networks', 'Data Simulation', 'Legal Compliance', 'Supervised Learning', 'Semi-supervised Learning', 'GraphQL', 'Experiment Tracking', 'Message Brokers', 'Calculus', 'Patent Law', 'Content Analytics', 'Business Rules', 'Blue Teaming', 'Normalization', 'Time Series Analysis', 'User Guides', 'Contract Management', 'Segmentation', 'Intellectual Property', 'Behavioral Analytics', 'Failure Modes and Effects Analysis', 'Computational Statistics', 'SPARQL', 'Oracle', 'Budgeting', 'Synthetic Data', 'Surveys', 'Web Scraping', 'Business Development', 'Data Loading', 'Interviews', 'Data Scaling', 'Regression Analysis', 'Lean', 'Ad Tech', 'Penetration Testing', 'Unani', 'Google Cloud', 'Feature Extraction', 'Data Masking', 'Market Research', 'Big Data', 'Customer Support', 'Regression Testing', 'TensorFlow', 'Identity Management', 'Random Search', 'Event Sourcing', 'Stream Processing', 'Compensation and Benefits', 'Conferences', 'Corporate Social Responsibility', 'Employee Wellness', 'Product Design', 'Encryption Standards', 'Diversity and Inclusion', 'Usability Testing', 'ROI', 'Board of Directors', 'Batch Processing', 'PyTorch', 'Knowledge Graphs', 'Profiling', 'Quantitative Research', 'Continuous Improvement', 'Cost Estimation', 'Robust AI', 'Networking', 'Trademark Law', 'Sprint Planning', 'Web Ontologies', 'Contracts', 'Copyright Law', 'Customer Insights', 'Regulatory Affairs', 'Media Relations', 'Sales Strategy', 'Optimization Algorithms', 'Risk Management', 'Regulations', 'Supply Chain Management', 'AI Policy', 'Data Synthesis', 'Lead Generation', 'Alerting'}
# Scores of similar users : {'U36': 23.159177829329273, 'U58': 21.053798026662975, 'U292': 21.290467263536573, 'U366': 23.159177829329273, 'U955': 21.053798026662975}

# %%
pickle.load(open('current_skills.pkl','rb'))
# Out:
#        Data Integration  Scalability  HIPAA  Onboarding  \
# U1                    0            0      0           0
# U2                    0            0      0           0
# U3                    0            0      0           0
# U4                    0            0      0           0
# U5                    0            0      0           0
# ...                 ...          ...    ...         ...
# U996                  0            0      0           0
# U997                  0            0      0           0
# U998                  0            0      0           0
# U999                  0            0      0           0
# U1000                 0            0      0           0
#
#        Research and Development  Knowledge Base  Recommendation Systems  \
# U1                            0               0                       0
# U2                            0               0                       0
# U3                            0               0                       1
# U4                            0               0                       0
# U5                            0               0                       0
# ...                         ...             ...                     ...
# U996                          0               0                       0
# U997                          0               0                       0
# U998                          0               0                       0
# U999                          0               0                       0
# U1000                         0               0                       0
#
#        Risk Register  Machine Learning  User Stories  ...  Knowledge Graphs  \
# U1                 0                 0             0  ...                 0
# U2                 0                 0             0  ...                 0
# U3                 0                 0             0  ...                 0
# U4                 0                 1             0  ...                 0
# U5                 0                 0             0  ...                 0
# ...              ...               ...           ...  ...               ...
# U996               0                 0             0  ...                 0
# U997               0                 0             0  ...                 0
# U998               0                 0             1  ...                 0
# U999               0                 0             0  ...                 0
# U1000              0                 0             0  ...                 0
#
#        Supply Chain Analytics  Design of Experiments  Customer Segmentation  \
# U1                          0                      0                      1
# U2                          0                      0                      0
# U3                          0                      0                      0
# U4                          0                      0                      1
# U5                          0                      0                      0
# ...                       ...                    ...                    ...
# U996                        0                      0                      1
# U997                        0                      0                      0
# U998                        0                      0                      1
# U999                        0                      0                      0
# U1000                       0                      0                      1
#
#        Trend Analysis  Project Scope  Media Relations  Talent Management  \
# U1                  0              0                0                  0
# U2                  0              0                0                  0
# U3                  0              0                0                  0
# U4                  0              0                0                  1
# U5                  0              0                0                  0
# ...               ...            ...              ...                ...
# U996                0              0                0                  0
# U997                0              0                0                  0
# U998                0              0                0                  0
# U999                0              0                0                  0
# U1000               1              1                1                  0
#
#        Data Synthesis  Alerting
# U1                  0         0
# U2                  0         0
# U3                  0         0
# U4                  0         0
# U5                  0         0
# ...               ...       ...
# U996                0         0
# U997                1         0
# U998                0         0
# U999                0         0
# U1000               0         0
#
# [1000 rows x 495 columns]

# %%
pickle.load(open('similarity_scores.pkl','rb'))
# Out:
#                U1          U2          U3          U4          U5        U6  \
# U1     100.000000    0.000000    0.000000    5.063697    8.451543  0.000000
# U2       0.000000  100.000000   11.322770   18.490007   11.572751  0.000000
# U3       0.000000   11.322770  100.000000    9.421114    0.000000  4.902903
# U4       5.063697   18.490007    9.421114  100.000000    4.279605  4.003204
# U5       8.451543   11.572751    0.000000    4.279605  100.000000  6.681531
# ...           ...         ...         ...         ...         ...       ...
# U996    13.187609    6.019293    4.089304   10.016708    0.000000  0.000000
# U997    16.035675   19.518001    3.314968    2.706660    4.517540  0.000000
# U998     6.593805    3.009646    4.089304   13.355611    5.572782  0.000000
# U999     0.000000    8.703883   11.826248    0.000000    0.000000  7.537784
# U1000    5.270463    9.622504    9.805807   16.012815    0.000000  8.333333
#
#               U7         U8         U9       U10  ...       U991       U992  \
# U1      0.000000   0.000000   5.345225  9.225312  ...   0.000000  12.649111
# U2     10.825318  17.407766   2.439750  8.421519  ...   9.622504  11.547005
# U3      0.000000   5.913124   6.629935  2.860648  ...   9.805807   3.922323
# U4      0.000000  14.484136   5.413320  4.671418  ...   8.006408   3.202563
# U5      0.000000   0.000000   0.000000  3.898406  ...  13.363062   5.345225
# ...          ...        ...        ...       ...  ...        ...        ...
# U996   10.425721   0.000000   3.524537  3.041495  ...   6.950480   8.340577
# U997    0.000000   5.096472   8.571429  7.396705  ...   2.817181  10.141851
# U998   10.425721   0.000000   7.049074  0.000000  ...   0.000000   0.000000
# U999    0.000000   0.000000   0.000000  8.795990  ...   0.000000   0.000000
# U1000   0.000000  20.100756  11.268723  4.862166  ...   8.333333   3.333333
#
#             U993       U994      U995        U996        U997        U998  \
# U1      6.324555   5.129892  0.000000   13.187609   16.035675    6.593805
# U2      2.886751   9.365858  0.000000    6.019293   19.518001    3.009646
# U3     11.766968   9.544271  8.770580    4.089304    3.314968    4.089304
# U4      6.405126   2.597622  7.161149   10.016708    2.706660   13.355611
# U5     10.690450   0.000000  0.000000    0.000000    4.517540    5.572782
# ...          ...        ...       ...         ...         ...         ...
# U996    8.340577   3.382550  0.000000  100.000000    7.049074    4.347826
# U997    0.000000  24.678382  3.779645    7.049074  100.000000   10.573611
# U998    8.340577   3.382550  0.000000    4.347826   10.573611  100.000000
# U999    0.000000   0.000000  0.000000    0.000000    5.096472   12.573892
# U1000  16.666667  13.518452  7.453560    3.475240    5.634362    6.950480
#
#              U999       U1000
# U1       0.000000    5.270463
# U2       8.703883    9.622504
# U3      11.826248    9.805807
# U4       0.000000   16.012815
# U5       0.000000    0.000000
# ...           ...         ...
# U996     0.000000    3.475240
# U997     5.096472    5.634362
# U998    12.573892    6.950480
# U999   100.000000    0.000000
# U1000    0.000000  100.000000
#
# [1000 rows x 1000 columns]

# %%
# Function to add a new user and recommend skills based on existing users
def add_new_user(new_user_id, current_skills, similarity_threshold=90.0):
    # Create a row for the new user in the existing DataFrame with current skills
    new_user_row = pd.Series(0, index=data.columns)
    for skill in current_skills:
        if skill in new_user_row.index:
            new_user_row[skill] = 1
    data.loc[new_user_id] = new_user_row

    # Recompute cosine similarity with the new user added
    cosine_sim = cosine_similarity(data)
    cosine_sim_df = pd.DataFrame(cosine_sim, index=data.index, columns=data.index)
    similarity_percentage_matrix = cosine_sim_df * 100
    similarity_percentage_df = pd.DataFrame(similarity_percentage_matrix, index=data.index, columns=data.index)
    
    # Save updated DataFrames to pickle files
    with open('current_skills.pkl', 'wb') as f:
        pickle.dump(data, f)
    
    with open('similarity_scores.pkl', 'wb') as f:
        pickle.dump(similarity_percentage_df, f)

    # Recommend skills for the new user
    recommended_skills, user_scores = recommend_skills(new_user_id, similarity_threshold)
    return recommended_skills, user_scores

# %%
# Example: Adding a new user U1001 with some skills
new_user_id = 'U104'
new_user_skills = ['Python', 'Data Visualization']
recommended_skills, user_scores = add_new_user(new_user_id, new_user_skills, similarity_threshold=21.0)
# Out:
# Similar users with scores for user U104: {'U104': {'U36': 23.159177829329273, 'U58': 21.053798026662975, 'U292': 21.290467263536573, 'U366': 23.159177829329273, 'U955': 21.053798026662975}}
# Current skills of user U104: {'Python', 'Data Visualization'}
# New skills from user U36 to recommend: {'Behavioral Analytics', 'Computational Statistics', 'CCPA', 'Data Loading', 'Backup and Recovery', 'Recommendation Systems', 'Benchmarking', 'Synthetic Data Generation', 'Qualitative Research', 'Ad Tech', 'Blue Teaming', 'Pharmacovigilance', 'Unani', 'Event Sourcing', 'Stream Processing', 'Social Media Analytics', 'Cybersecurity', 'Data Augmentation', 'User Feedback', 'Corporate Social Responsibility', 'Employee Wellness', 'Flowcharts', 'Diversity and Inclusion', 'Vulnerability Assessment', 'Usability Testing', 'Marketing Automation', 'Board of Directors', 'Batch Processing', 'Fault Tolerance', 'Ethical Hacking', 'Lab Experiments', 'Workplace Culture', 'Data Synthesis', 'Generative Adversarial Networks', 'Legal Compliance', 'SWOT Analysis', 'Networking', 'Semi-supervised Learning', 'Contracts', 'Fraud Detection', 'Regulatory Affairs', 'Experiment Tracking', 'Patent Law', 'Process Optimization', 'Business Rules', 'Documentation', 'Lead Generation', 'Alerting'}
# New skills from user U58 to recommend: {'UI Design', 'Google Cloud', 'Segmentation', 'Model Deployment', 'Hybrid Filtering', 'Data Aggregation', 'Collaborations', 'Optimization Algorithms', 'Random Search', 'Content Analytics', 'Artificial Intelligence', 'Profiling'}
# New skills from user U292 to recommend: {'Product Design', 'Scalability', 'SPARQL', 'Go-to-Market Strategy', 'Power BI', 'Data Cataloging', 'Business Development', 'CQRS', 'Model Maintenance', 'Data Transformation', 'Service Management', 'Feature Extraction', 'Data Masking', 'Model Deployment', 'Customer Insights', 'Customer Support', 'Cost-Benefit Analysis', 'Message Brokers', 'R Programming', 'Technical Writing', 'Vendor Management', 'Blue Teaming', 'Statistics'}
# New skills from user U366 to recommend: {'Azure', 'Failure Modes and Effects Analysis', 'Oracle', 'Go-to-Market Strategy', 'Power BI', 'Synthetic Data', 'Mediation', 'Collaborative Filtering', 'Interviews', 'Lean', 'Penetration Testing', 'ITIL', 'Market Research', 'Alerting', 'Unsupervised Learning', 'A/B Testing', 'Identity Management', 'Logistics Management', 'Occupational Health', 'Agricultural Analytics', 'Social Media Analytics', 'Compensation and Benefits', 'Hybrid Filtering', 'Notebooks', 'Continuous Deployment', 'Scrum', 'PyTorch', 'Metrics', 'Compliance Management', 'Smart Cities', 'Data Simulation', 'Quantitative Research', 'Cost Estimation', 'Semi-supervised Learning', 'GraphQL', 'Sprint Planning', 'Web Ontologies', 'Copyright Law', 'Fraud Detection', 'Sales Strategy', 'Regulations', 'Supply Chain Management', 'AI Policy', 'Business Rules', 'Documentation', 'Continuous Improvement', 'Information Security', 'Wearable Technology'}
# New skills from user U955 to recommend: {'Contract Management', 'Intellectual Property', 'Budgeting', 'Web Scraping', 'Surveys', 'Data Scaling', 'Regression Analysis', 'Data Transformation', 'Gantt Charts', 'Big Data', 'Market Research', 'Data Sharing', 'Problem Management', 'Regression Testing', 'TensorFlow', 'Random Search', 'Ethics in AI', 'Metadata Management', 'Data Transparency', 'Operations Research', 'Conferences', 'Load Testing', 'Employee Wellness', 'Encryption Standards', 'Continuous Deployment', 'Agile Practices', 'Prototyping', 'SQL', 'Product Management', 'ROI', 'Data Management Tools', 'Discrete Mathematics', 'Knowledge Graphs', 'Workplace Culture', 'Supervised Learning', 'Robust AI', 'SWOT Analysis', 'Trademark Law', 'Web Ontologies', 'Fraud Detection', 'Media Relations', 'Sales Strategy', 'Calculus', 'R Programming', 'Risk Management', 'Normalization', 'Time Series Analysis', 'User Guides'}

# %%
print(f"Recommended skills for new user {new_user_id}: {recommended_skills}")
print(f"Scores of similar users for new user {new_user_id}: {user_scores}")
# Out:
# Recommended skills for new user U104: {'Azure', 'Scalability', 'Power BI', 'Mediation', 'Recommendation Systems', 'Unsupervised Learning', 'Problem Management', 'Agricultural Analytics', 'Ethics in AI', 'Metadata Management', 'Data Transparency', 'Statistics', 'Data Augmentation', 'Load Testing', 'Flowcharts', 'Continuous Deployment', 'Vulnerability Assessment', 'Prototyping', 'Data Management Tools', 'Marketing Automation', 'Lab Experiments', 'Ethical Hacking', 'Smart Cities', 'Generative Adversarial Networks', 'Supervised Learning', 'Semi-supervised Learning', 'Experiment Tracking', 'Collaborations', 'Technical Writing', 'Content Analytics', 'Process Optimization', 'Business Rules', 'Documentation', 'Normalization', 'Time Series Analysis', 'Intellectual Property', 'Budgeting', 'Oracle', 'Go-to-Market Strategy', 'Data Aggregation', 'Data Scaling', 'Data Loading', 'Regression Analysis', 'Benchmarking', 'Ad Tech', 'Penetration Testing', 'Unani', 'Feature Extraction', 'Data Masking', 'Market Research', 'Customer Support', 'Data Sharing', 'Regression Testing', 'Identity Management', 'Random Search', 'Event Sourcing', 'Compensation and Benefits', 'Hybrid Filtering', 'Notebooks', 'Employee Wellness', 'Product Design', 'Encryption Standards', 'SQL', 'ROI', 'Board of Directors', 'PyTorch', 'Quantitative Research', 'SWOT Analysis', 'Robust AI', 'Networking', 'Trademark Law', 'Sprint Planning', 'Contracts', 'Customer Insights', 'Cost-Benefit Analysis', 'Regulatory Affairs', 'Sales Strategy', 'Risk Management', 'Regulations', 'AI Policy', 'Pharmacovigilance', 'Continuous Improvement', 'Information Security', 'Collaborative Filtering', 'Backup and Recovery', 'Synthetic Data Generation', 'Gantt Charts', 'Model Deployment', 'ITIL', 'A/B Testing', 'Logistics Management', 'Occupational Health', 'Vendor Management', 'Cybersecurity', 'Operations Research', 'User Feedback', 'Agile Practices', 'Product Management', 'Data Cataloging', 'Discrete Mathematics', 'Scrum', 'Fault Tolerance', 'Metrics', 'Compliance Management', 'Model Maintenance', 'Service Management', 'Data Simulation', 'Legal Compliance', 'GraphQL', 'Message Brokers', 'Calculus', 'R Programming', 'Patent Law', 'Blue Teaming', 'User Guides', 'Contract Management', 'Segmentation', 'Behavioral Analytics', 'Failure Modes and Effects Analysis', 'Computational Statistics', 'SPARQL', 'CCPA', 'Synthetic Data', 'Web Scraping', 'Surveys', 'Business Development', 'Interviews', 'CQRS', 'Lean', 'Qualitative Research', 'Data Transformation', 'Artificial Intelligence', 'Google Cloud', 'Big Data', 'TensorFlow', 'Stream Processing', 'Social Media Analytics', 'Conferences', 'Corporate Social Responsibility', 'Diversity and Inclusion', 'Usability Testing', 'Batch Processing', 'Knowledge Graphs', 'Workplace Culture', 'Profiling', 'Cost Estimation', 'UI Design', 'Web Ontologies', 'Copyright Law', 'Fraud Detection', 'Media Relations', 'Optimization Algorithms', 'Supply Chain Management', 'Data Synthesis', 'Lead Generation', 'Alerting', 'Wearable Technology'}
# Scores of similar users for new user U104: {'U36': 23.159177829329273, 'U58': 21.053798026662975, 'U292': 21.290467263536573, 'U366': 23.159177829329273, 'U955': 21.053798026662975}
